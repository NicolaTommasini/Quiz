# %% [markdown]
# # Birthday Paradox

# %% [markdown]
# ### Birthday Paradox

# %%
# Import
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def birth_prob(k):
    days = 365
    prob = math.factorial(days)/((days**k)* math.factorial(days - k))    
    return prob

# %%
cum_prob = []
days = 365
for i in range(0,days):
    cum_prob.append(birth_prob(i))
cum_prob_pairs = [1-x for x in cum_prob]

# %%
plt.figure(figsize=(25,10))
plt.plot(cum_prob, label = "1 - Prob", c = 'b' )
plt.plot(cum_prob_pairs, label = "Probability of a pair", c = 'r')
plt.xlabel('# people')
plt.ylabel("Cumulative Probability")
plt.title("Birthday Paradox - Cumulative distribution")
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.plot(cum_prob, label = "1 - Prob", c = 'b' )
plt.plot(cum_prob_pairs, label = "Probability of a pair", c = 'r')
plt.xlabel('# people')
plt.ylabel("Cumulative Probability")
plt.title("Birthday Paradox - Cumulative distribution \n k = 23")
plt.axhline(y = 0.5, xmax=23,  c = 'k', linestyle="--")
plt.axvline(x = 23, ymax=0.5,  c = 'k', linestyle="--")
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.plot(cum_prob, label = "1 - Prob", c = 'b' )
plt.plot(cum_prob_pairs, label = "Probability of a pair", c = 'r')
plt.xlabel('# people')
plt.ylabel("Cumulative Probability")
plt.title("Birthday Paradox - Cumulative distribution \n k = 75")
plt.axhline(y = 0.995, xmax=23,  c = 'k', linestyle="--")
plt.axvline(x = 75, ymax=0.99,  c = 'k', linestyle="--")
plt.legend(loc='best')
plt.grid()
plt.show()
